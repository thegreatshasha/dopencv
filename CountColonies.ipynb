# %%
""" Do some common imports """
import cv2
import matplotlib.pyplot as plt
import numpy as np
import sys
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 15, 15

# %% [markdown]
# Let's start off by loading the images

# %%
FILES = ['images/set1/T_342.jpg', 'images/set1/G_732.jpg', 'images/set1/Q_222.jpg', 'images/set1/E_266.jpg', 'images/set1/J_1036.jpg', 'images/set1/Z_600.jpg']
print FILES
# Out:
# ['images/set1/T_342.jpg', 'images/set1/G_732.jpg', 'images/set1/Q_222.jpg', 'images/set1/E_266.jpg', 'images/set1/J_1036.jpg', 'images/set1/Z_600.jpg']

# %% [markdown]
# Loading the image

# %%
img = cv2.imread('images/set1/C_593.jpg', 0)
plt.imshow(img,cmap='gray')

# %%
plt.imshow(img, cmap='gray')

# %%
h, w = img.shape

# %% [markdown]
# Ok these images are huge, time to resize them, how do we resize them again?

# %%
if h > 600:
    img = cv2.resize(img, (w/4, h/4))

# %%
plt.imshow(img, cmap='gray')

# %%
print img.shape
# Out:
# (512, 776)

# %% [markdown]
# Ok this size is fine for applying algos> Let's try out different thresholding methods now

# %%
thresh_inrange = cv2.inRange(img, 200, 255)
plt.imshow(thresh_inrange, cmap='gray')

# %% [markdown]
# In order to compare it to adaptive, otsu's method and canary, let's also plot these as well.

# %%
rect,thresh_otsu = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.imshow(thresh_otsu, cmap='gray')

# %% [markdown]
# Let's plot the canny as well

# %%
from detect import auto_canny
thresh_canny = auto_canny(img)
plt.imshow(thresh_canny, cmap='gray')

# %% [markdown]
# While we are at it, why not try erosion as well?
