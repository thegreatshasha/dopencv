# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2
import sys
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 15, 15
img = cv2.imread('images/coins.jpg', 0)
plt.imshow(img, cmap='gray')
ret, thresh = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
plt.imshow(thresh, cmap='gray')
kernel = np.ones((3,3), np.uint8)
opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=2)
plt.imshow(opening, cmap='gray')
dilated_img = cv2.dilate(opening, kernel, iterations=3)
plt.imshow(dilated_img, cmap='gray')
dist_transform = cv2.distanceTransform(opening, cv2.DISTANCE_L2, 5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-3e3531114295> in <module>()
#      15 dilated_img = cv2.dilate(opening, kernel, iterations=3)
#      16 plt.imshow(dilated_img, cmap='gray')
# ---> 17 dist_transform = cv2.distanceTransform(opening, cv2.DISTANCE_L2, 5)
#
# AttributeError: module 'cv2' has no attribute 'DISTANCE_L2'
