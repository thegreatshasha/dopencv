# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2
import sys
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 15, 15

# %%
from SimpleCV import *
im = Image("/Users/shashwat/workspace/dopencv/images/set1/C_593.tif")
r,g,b = im.splitChannels()
cellmask = g.equalize().threshold(90).invert()
masksize = cellmask.getGrayNumpy().sum()/255.
cellsize = 21*21 # premeasured cell size
cellnum = masksize/cellsize
print(cellnum)
# Out:
# 13315.7346939

# %%
plt.imshow(cellmask.getGrayNumpy(), cmap='gray')

# %%
cellmask.getGrayNumpy().hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-9e289e18368e> in <module>()
# ----> 1 cellmask.getGrayNumpy().hist()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'hist'

# %%
plt.hist(im.getGrayNumpy().ravel(),256,[0,256])
plt.title('Histogram for gray scale picture')
plt.show()

# %%
im
# Out:
# <SimpleCV.Image Object size:(768, 576), filename: (/Users/shashwat/Downloads/s58Hl.jpg), at memory location: (0x115de5f80)>
