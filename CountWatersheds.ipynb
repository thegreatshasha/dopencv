# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import sys
# %matplotlib inline
from pylab import rcParams
from helpers import scaled_resize
rcParams['figure.figsize'] = 15, 15

# %%
input_file = 'images/set1/A_241.tif'

img = cv2.imread(input_file, 0)
img2 = cv2.imread(input_file)

plt.imshow(img, cmap='gray')

# %%
contours, hier = cv2.findContours(img,mode=cv2.RETR_LIST, method=cv2.CHAIN_APPROX_NONE)
print len(contours)
cv2.drawContours(img2, contours, -1, 255, 2)
# Out:
# 212

# %%
plt.imshow(img2, cmap='gray')
